# %%
import sys
# 将项目根目录添加到 path 中
sys.path.append('../..')

# %%
import matplotlib.pyplot as plt

from lenet.utils.rbf_weight import RBF_WEIGHT

# %%
RBF_WEIGHT.shape
# Out:
# (84, 10)

# %%
fig, axs = plt.subplots(2, 5, figsize=(12, 7))
for i in range(10):
    x, y = i // 5, i % 5
    axs[x, y].set_title(str(i))
    axs[x,y].imshow(RBF_WEIGHT[:, i].reshape(12, 7), cmap=plt.cm.Greys)
